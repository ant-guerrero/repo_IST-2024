# %% [markdown]
# # E02: Días en calma internacionales

# %%
# importamos las librerías que vamos a necesitar
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Obtenemos los días en calma internacionales para un mes determinado desde esta web: http://wdc.kugi.kyoto-u.ac.jp/qddays/index.html
# ### <span style="color:green">Comprueba que los días en calma para el mes de marzo de 2015 son los siguientes: </span>

# %%
# días en calma para el mes de marzo de 2015
qs=['10','30','06','14','09']

# %% [markdown]
# ## P01: ¿Has tenido que cambiar algún día?

# %% [markdown]
# ### R01:

# %% [markdown]
# ## Los observatorios usados para crear el índice Dst podemos obternerlos de la descripción pública en la web de Kyoto WDC: http://wdc.kugi.kyoto-u.ac.jp/dstdir/dst2/onDstindex.html
# ### <span style="color:green">Comprueba que los códigos de las estaciones usadas son los siguientes: </span>

# %%
# observatorios usados para el índice Dst
obs=['her','hon','kak','sjg']

# %% [markdown]
# ## P02: ¿Son correctos?

# %% [markdown]
# ### R02:

# %%
# crear nombres de ficheros para los cuatro observatorios y los cinco días en calma
for qi in qs:
    for o in obs:
        folder='data/'
        filename=folder + o + '/' + o + '202410' + qi + 'qmin.min'
        print(filename)
# Out:
# data/her/her20241010qmin.min
# data/hon/hon20241010qmin.min
# data/kak/kak20241010qmin.min
# data/sjg/sjg20241010qmin.min
# data/her/her20241030qmin.min
# data/hon/hon20241030qmin.min
# data/kak/kak20241030qmin.min
# data/sjg/sjg20241030qmin.min
# data/her/her20241006qmin.min
# data/hon/hon20241006qmin.min
# data/kak/kak20241006qmin.min
# data/sjg/sjg20241006qmin.min
# data/her/her20241014qmin.min
# data/hon/hon20241014qmin.min
# data/kak/kak20241014qmin.min
# data/sjg/sjg20241014qmin.min
# data/her/her20241009qmin.min
# data/hon/hon20241009qmin.min
# data/kak/kak20241009qmin.min
# data/sjg/sjg20241009qmin.min

# %% [markdown]
# ## P03: ¿Crees que se podrían leer los ficheros que tenemos en la carpeta dst_stations con los nombres generados?

# %% [markdown]
# ### R03:

# %%
filename='data/sjg/sjg20241025qmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=23,names=names, colspecs=colspecs)
plt.plot(df.c1)

filename='data/sjg/sjg20241027qmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=23,names=names, colspecs=colspecs)
plt.plot(df.c1)

# %% [markdown]
# ## P04: ¿Qué muestra la figura anterior?, cantidad de datos, observatorios origen, forma de la curva ... ¿alguna otra observación?

# %% [markdown]
# ### R04:

# %%
filename='data/sjg/sjg20241025qmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=23,names=names, colspecs=colspecs)
plt.plot(df.c1)

filename='data/sjg/sjg20241010qmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=23,names=names, colspecs=colspecs)
plt.plot(df.c1)

# %% [markdown]
# ## P05: Comenta las diferencias con la anterior y a qué crees que son debidas

# %% [markdown]
# ### R05:

# %%
filename='data/kak/kak20241025qmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=21,names=names, colspecs=colspecs)
plt.plot(df.c1)


filename='data/sjg/sjg20241025qmin.min'
names=['date','time','doy','c1','c2','c3','c4']
colspecs=[(0,10), (12,23), (25,27), (32,40), (42,50), (52,60), (62,70)]
df=pd.read_fwf(filename,header=23,names=names, colspecs=colspecs)
plt.plot(df.c1)

# %% [markdown]
# ## P06: ¿Qué ocurre en esta gráfica?, comenta si crees que es correcta y porqué se observan dos líneas paralelas.

# %% [markdown]
# ### R06:

# %% [markdown]
# ## A07: Se te ocurre alguna forma de poder mostrar los datos de diferentes observatorios superpuestos en una misma gráfica?. Escribe cógido y pruébalo si lo consideras apropiado.

# %% [markdown]
# ### R07:
